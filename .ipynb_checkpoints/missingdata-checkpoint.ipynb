# %%
import pandas as pd

# %%
var = pd.read_csv("C:\\Users\\iamad\\AI and ML\\pandas_missing_data.csv")
var
# Out:
#       Name   Age         City   Salary
# 0    Alice  25.0     New York  50000.0
# 1      Bob  30.0  Los Angeles  60000.0
# 2  Charlie   NaN      Chicago  55000.0
# 3    David  22.0          NaN      NaN
# 4      Eva  29.0      Houston  52000.0
# 5    Frank   NaN      Phoenix  58000.0
# 6    Grace  35.0          NaN      NaN
# 7   Hannah  40.0        Miami  62000.0
# 8    alice  34.0     New York      NaN

# %%
var.dropna()
# Out:
#      Name   Age         City   Salary
# 0   Alice  25.0     New York  50000.0
# 1     Bob  30.0  Los Angeles  60000.0
# 4     Eva  29.0      Houston  52000.0
# 7  Hannah  40.0        Miami  62000.0

# %%
var.dropna(subset = ["Salary"])
# Out:
#       Name   Age         City   Salary
# 0    Alice  25.0     New York  50000.0
# 1      Bob  30.0  Los Angeles  60000.0
# 2  Charlie   NaN      Chicago  55000.0
# 4      Eva  29.0      Houston  52000.0
# 5    Frank   NaN      Phoenix  58000.0
# 7   Hannah  40.0        Miami  62000.0

# %%
var = pd.read_csv("C:\\Users\\iamad\\AI and ML\\pandas_missing_data.csv")
var
# Out:
#       Name   Age         City   Salary
# 0    Alice  25.0     New York  50000.0
# 1      Bob  30.0  Los Angeles  60000.0
# 2  Charlie   NaN      Chicago  55000.0
# 3    David  22.0          NaN      NaN
# 4      Eva  29.0      Houston  52000.0
# 5    Frank   NaN      Phoenix  58000.0
# 6    Grace  35.0          NaN      NaN
# 7   Hannah  40.0        Miami  62000.0
# 8    alice  34.0     New York      NaN

# %%
var.dropna(thresh = 3)
# Out:
#       Name   Age         City   Salary
# 0    Alice  25.0     New York  50000.0
# 1      Bob  30.0  Los Angeles  60000.0
# 2  Charlie   NaN      Chicago  55000.0
# 4      Eva  29.0      Houston  52000.0
# 5    Frank   NaN      Phoenix  58000.0
# 7   Hannah  40.0        Miami  62000.0
# 8    alice  34.0     New York      NaN
